# %% [markdown]
# ## Introduction:
#
# This report presents the results of a sentiment analysis conducted on a sample dataset received from kaggle.com website. The dataset showed the comments by user on twiter on sport analysis. I will be domonstrating how the data would be cleaned, pre-processed and ready for sentiment analysis using NLTK Python library. The comment column would be tokenized and a sentiment analysis would be performed to gain further insights.

# %% [markdown]
# ## Data Preprocessing

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')

from string import punctuation 
from nltk.tokenize import word_tokenize

from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
        
df = pd.read_csv('twitter_data.csv')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\olanr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\olanr\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\olanr\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df.head()
# Out:
#                                         twitter_link  \
# 0  https://twitter.com/ActionBitters/status/17563...
# 1  https://twitter.com/MohammedSanogo/status/1756...
# 2  https://twitter.com/DejiAdesogan/status/175628...
# 3  https://twitter.com/ssozinha_/status/175633760...
# 4  https://twitter.com/infinixuganda/status/17562...
#
#                                                 text  \
# 0  Final AFCON Action, Predict the final score be...
# 1  Ne perdons pas de vue l'objectif. #mohammedsan...
# 2  "Captain @Ahmedmusa718 is special &  important...
# 3  If you don’t know what’s happening in DR Congo...
# 4  It’s the FINALS😍 Predict the correct score bef...
#
#                           date  likes  comments
# 0   Feb 10, 2024 · 5:17 PM UTC     26        48
# 1  Feb 10, 2024 · 10:30 AM UTC    630         5
# 2  Feb 10, 2024 · 11:49 AM UTC    891        14
# 3   Feb 10, 2024 · 3:21 PM UTC     32         0
# 4   Feb 10, 2024 · 6:23 AM UTC    166       257

# %%
df.shape
# Out:
# (100, 5)

# %%
# Check data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   twitter_link  100 non-null    object
#  1   text          100 non-null    object
#  2   date          100 non-null    object
#  3   likes         100 non-null    int64
#  4   comments      100 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB

# %%
# Clean Data

# Drop rows with missing values
df = df.dropna()

# Remove duplicates
df = df.drop_duplicates()
# Remove unnessary Characters
def remove_unnecessary_characters(text):
    text = re.sub(r'@', '', str(text))
    text = re.sub(r'<.*?#>', '', str(text))
    text = re.sub(r'[^a-zA-Z0-9\s]', '', str(text))
    text = re.sub(r'\s+', ' ', str(text)).strip()
    return text
df['text'] = df['text'].apply(remove_unnecessary_characters)

df.head()
# Out:
#                                         twitter_link  \
# 0  https://twitter.com/ActionBitters/status/17563...
# 1  https://twitter.com/MohammedSanogo/status/1756...
# 2  https://twitter.com/DejiAdesogan/status/175628...
# 3  https://twitter.com/ssozinha_/status/175633760...
# 4  https://twitter.com/infinixuganda/status/17562...
#
#                                                 text  \
# 0  Final AFCON Action Predict the final score bet...
# 1  Ne perdons pas de vue lobjectif mohammedsanogo...
# 2  Captain Ahmedmusa718 is special important to t...
# 3  If you dont know whats happening in DR Congo a...
# 4  Its the FINALS Predict the correct score befor...
#
#                           date  likes  comments
# 0   Feb 10, 2024 · 5:17 PM UTC     26        48
# 1  Feb 10, 2024 · 10:30 AM UTC    630         5
# 2  Feb 10, 2024 · 11:49 AM UTC    891        14
# 3   Feb 10, 2024 · 3:21 PM UTC     32         0
# 4   Feb 10, 2024 · 6:23 AM UTC    166       257

# %% [markdown]
# ##  Model Implementation

# %%
# Tokenizaton 

def tokenize_text(text):
    try:
        text = str(text)
        tokens = word_tokenize(text)
        return tokens
    except Exception as e:
        print(f"Error tokenizing text: {e}")
        return []
df['tokens'] = df['text'].apply(tokenize_text)
df.head()
# Out:
#                                         twitter_link  \
# 0  https://twitter.com/ActionBitters/status/17563...
# 1  https://twitter.com/MohammedSanogo/status/1756...
# 2  https://twitter.com/DejiAdesogan/status/175628...
# 3  https://twitter.com/ssozinha_/status/175633760...
# 4  https://twitter.com/infinixuganda/status/17562...
#
#                                                 text  \
# 0  Final AFCON Action Predict the final score bet...
# 1  Ne perdons pas de vue lobjectif mohammedsanogo...
# 2  Captain Ahmedmusa718 is special important to t...
# 3  If you dont know whats happening in DR Congo a...
# 4  Its the FINALS Predict the correct score befor...
#
#                           date  likes  comments  \
# 0   Feb 10, 2024 · 5:17 PM UTC     26        48
# 1  Feb 10, 2024 · 10:30 AM UTC    630         5
# 2  Feb 10, 2024 · 11:49 AM UTC    891        14
# 3   Feb 10, 2024 · 3:21 PM UTC     32         0
# 4   Feb 10, 2024 · 6:23 AM UTC    166       257
#
#                                               tokens
# 0  [Final, AFCON, Action, Predict, the, final, sc...
# 1  [Ne, perdons, pas, de, vue, lobjectif, mohamme...
# 2  [Captain, Ahmedmusa718, is, special, important...
# 3  [If, you, dont, know, whats, happening, in, DR...
# 4  [Its, the, FINALS, Predict, the, correct, scor...

# %%
# Data Normalization
def normalize_text(text):
    if isinstance(text, str):
        text = text.lower()
        text = re.sub(r'[^\w\s]', '', text)
        text = re.sub(r'\s+', ' ', text).strip()
    else:
        text = str(text)
    return text
df['normalized_text'] = df['text'].apply(normalize_text)

df.head()
# Out:
#                                         twitter_link  \
# 0  https://twitter.com/ActionBitters/status/17563...
# 1  https://twitter.com/MohammedSanogo/status/1756...
# 2  https://twitter.com/DejiAdesogan/status/175628...
# 3  https://twitter.com/ssozinha_/status/175633760...
# 4  https://twitter.com/infinixuganda/status/17562...
#
#                                                 text  \
# 0  Final AFCON Action Predict the final score bet...
# 1  Ne perdons pas de vue lobjectif mohammedsanogo...
# 2  Captain Ahmedmusa718 is special important to t...
# 3  If you dont know whats happening in DR Congo a...
# 4  Its the FINALS Predict the correct score befor...
#
#                           date  likes  comments  \
# 0   Feb 10, 2024 · 5:17 PM UTC     26        48
# 1  Feb 10, 2024 · 10:30 AM UTC    630         5
# 2  Feb 10, 2024 · 11:49 AM UTC    891        14
# 3   Feb 10, 2024 · 3:21 PM UTC     32         0
# 4   Feb 10, 2024 · 6:23 AM UTC    166       257
#
#                                               tokens  \
# 0  [Final, AFCON, Action, Predict, the, final, sc...
# 1  [Ne, perdons, pas, de, vue, lobjectif, mohamme...
# 2  [Captain, Ahmedmusa718, is, special, important...
# 3  [If, you, dont, know, whats, happening, in, DR...
# 4  [Its, the, FINALS, Predict, the, correct, scor...
#
#                                      normalized_text
# 0  final afcon action predict the final score bet...
# 1  ne perdons pas de vue lobjectif mohammedsanogo...
# 2  captain ahmedmusa718 is special important to t...
# 3  if you dont know whats happening in dr congo a...
# 4  its the finals predict the correct score befor...

# %%
def remove_stopwords(text):
    if isinstance(text, str):
        words = text.split()        
        filtered_words = [word for word in words if word.lower() not in stopwords.words('english')]
        filtered_text = ' '.join(filtered_words)
    else:
        filtered_text = ''
    return filtered_text
df['text_without_stopwords'] = df['text'].apply(remove_stopwords)

df.head()
# Out:
#                                         twitter_link  \
# 0  https://twitter.com/ActionBitters/status/17563...
# 1  https://twitter.com/MohammedSanogo/status/1756...
# 2  https://twitter.com/DejiAdesogan/status/175628...
# 3  https://twitter.com/ssozinha_/status/175633760...
# 4  https://twitter.com/infinixuganda/status/17562...
#
#                                                 text  \
# 0  Final AFCON Action Predict the final score bet...
# 1  Ne perdons pas de vue lobjectif mohammedsanogo...
# 2  Captain Ahmedmusa718 is special important to t...
# 3  If you dont know whats happening in DR Congo a...
# 4  Its the FINALS Predict the correct score befor...
#
#                           date  likes  comments  \
# 0   Feb 10, 2024 · 5:17 PM UTC     26        48
# 1  Feb 10, 2024 · 10:30 AM UTC    630         5
# 2  Feb 10, 2024 · 11:49 AM UTC    891        14
# 3   Feb 10, 2024 · 3:21 PM UTC     32         0
# 4   Feb 10, 2024 · 6:23 AM UTC    166       257
#
#                                               tokens  \
# 0  [Final, AFCON, Action, Predict, the, final, sc...
# 1  [Ne, perdons, pas, de, vue, lobjectif, mohamme...
# 2  [Captain, Ahmedmusa718, is, special, important...
# 3  [If, you, dont, know, whats, happening, in, DR...
# 4  [Its, the, FINALS, Predict, the, correct, scor...
#
#                                      normalized_text  \
# 0  final afcon action predict the final score bet...
# 1  ne perdons pas de vue lobjectif mohammedsanogo...
# 2  captain ahmedmusa718 is special important to t...
# 3  if you dont know whats happening in dr congo a...
# 4  its the finals predict the correct score befor...
#
#                               text_without_stopwords
# 0  Final AFCON Action Predict final score Nigeria...
# 1  Ne perdons pas de vue lobjectif mohammedsanogo...
# 2  Captain Ahmedmusa718 special important team as...
# 3  dont know whats happening DR Congo national pl...
# 4  FINALS Predict correct score kickoff tomorrows...

# %%
def sentiment_analyzer(text):
    sid = SentimentIntensityAnalyzer()
    sentiment_scores = sid.polarity_scores(text)
    sentiment = sentiment_scores['compound'] 
    
    #Print Sentiment Scores
    print(sentiment_scores)
    
    tokens = nltk.word_tokenize(text)
    wordScores = []
    for token in tokens:
        wordScore = sid.polarity_scores(token)
        wordScores.append((token, wordScore))
    if sentiment >= 0.05:
        return 'Positive'
    elif sentiment <=-0.05:
        return 'Negative'
    else:
        return 'Neutral'

df['sentiment'] = df['text'].apply(sentiment_analyzer)
# Out:
# {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.7964}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.9001}
# {'neg': 0.049, 'neu': 0.879, 'pos': 0.072, 'compound': 0.1779}
# {'neg': 0.038, 'neu': 0.701, 'pos': 0.261, 'compound': 0.8779}
# {'neg': 0.069, 'neu': 0.713, 'pos': 0.218, 'compound': 0.7717}
# {'neg': 0.053, 'neu': 0.91, 'pos': 0.036, 'compound': -0.2342}
# {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'compound': 0.8625}
# {'neg': 0.033, 'neu': 0.831, 'pos': 0.136, 'compound': 0.9721}
# {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.9555}
# {'neg': 0.0, 'neu': 0.661, 'pos': 0.339, 'compound': 0.9153}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'compound': 0.4404}
# {'neg': 0.06, 'neu': 0.94, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.296, 'neu': 0.704, 'pos': 0.0, 'compound': -0.743}
# {'neg': 0.0, 'neu': 0.899, 'pos': 0.101, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.941, 'pos': 0.059, 'compound': 0.34}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.028, 'neu': 0.62, 'pos': 0.352, 'compound': 0.9531}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'compound': -0.4588}
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.25}
# {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.6705}
# {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.8834}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.092, 'neu': 0.881, 'pos': 0.027, 'compound': -0.4767}
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.9001}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.8176}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.056, 'neu': 0.823, 'pos': 0.12, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.094, 'neu': 0.878, 'pos': 0.028, 'compound': -0.4767}
# {'neg': 0.15, 'neu': 0.784, 'pos': 0.066, 'compound': -0.3624}
# {'neg': 0.081, 'neu': 0.701, 'pos': 0.218, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.296}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 0.731, 'pos': 0.269, 'compound': 0.8957}
# {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.7783}
# {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'compound': 0.8176}
# {'neg': 0.195, 'neu': 0.604, 'pos': 0.201, 'compound': 0.0516}
# {'neg': 0.095, 'neu': 0.623, 'pos': 0.282, 'compound': 0.7269}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'compound': 0.9049}
# {'neg': 0.128, 'neu': 0.872, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.941, 'pos': 0.059, 'compound': 0.296}
# {'neg': 0.082, 'neu': 0.718, 'pos': 0.199, 'compound': 0.6597}
# {'neg': 0.05, 'neu': 0.773, 'pos': 0.177, 'compound': 0.6801}
# {'neg': 0.094, 'neu': 0.878, 'pos': 0.028, 'compound': -0.4767}
# {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.5859}
# {'neg': 0.125, 'neu': 0.713, 'pos': 0.162, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.8966}
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8885}
# {'neg': 0.185, 'neu': 0.58, 'pos': 0.235, 'compound': 0.1769}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.163, 'neu': 0.732, 'pos': 0.106, 'compound': -0.4215}
# {'neg': 0.094, 'neu': 0.878, 'pos': 0.028, 'compound': -0.4767}
# {'neg': 0.0, 'neu': 0.568, 'pos': 0.432, 'compound': 0.5859}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.145, 'neu': 0.708, 'pos': 0.148, 'compound': 0.0258}
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.6369}
# {'neg': 0.068, 'neu': 0.932, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 0.814, 'pos': 0.186, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.9001}
# {'neg': 0.053, 'neu': 0.858, 'pos': 0.088, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.704, 'pos': 0.296, 'compound': 0.743}
# {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'compound': 0.6808}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.337, 'neu': 0.663, 'pos': 0.0, 'compound': -0.765}
# {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.055, 'neu': 0.826, 'pos': 0.119, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.6486}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.611, 'pos': 0.389, 'compound': 0.7906}
# {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.8176}
# {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'compound': 0.8979}
# {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.8442}
# {'neg': 0.0, 'neu': 0.783, 'pos': 0.217, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'compound': 0.5859}
# {'neg': 0.049, 'neu': 0.535, 'pos': 0.416, 'compound': 0.9413}

# %%
df.head(20)
# Out:
#                                          twitter_link  \
# 0   https://twitter.com/ActionBitters/status/17563...
# 1   https://twitter.com/MohammedSanogo/status/1756...
# 2   https://twitter.com/DejiAdesogan/status/175628...
# 3   https://twitter.com/ssozinha_/status/175633760...
# 4   https://twitter.com/infinixuganda/status/17562...
# 5   https://twitter.com/NigeriaStories/status/1756...
# 6   https://twitter.com/StanleyOkolie9/status/1756...
# 7   https://twitter.com/KelechiAFC/status/17562801...
# 8   https://twitter.com/osasuo/status/175604647295...
# 9   https://twitter.com/osasuo/status/175604910681...
# 10  https://twitter.com/papilokanu/status/17560906...
# 11  https://twitter.com/NigeriaStories/status/1756...
# 12  https://twitter.com/DrJohnBishop/status/175618...
# 13  https://twitter.com/Eagle1025FM/status/1756391...
# 14  https://twitter.com/Feyishayo31/status/1756394...
# 15  https://twitter.com/KelechiAFC/status/17562335...
# 16  https://twitter.com/wassuptimmy/status/1756394...
# 17  https://twitter.com/BarOneRacing/status/175639...
# 18  https://twitter.com/Omoolajide/status/17563939...
# 19  https://twitter.com/kuwait_magix/status/175638...
#
#                                                  text  \
# 0   Final AFCON Action Predict the final score bet...
# 1   Ne perdons pas de vue lobjectif mohammedsanogo...
# 2   Captain Ahmedmusa718 is special important to t...
# 3   If you dont know whats happening in DR Congo a...
# 4   Its the FINALS Predict the correct score befor...
# 5   The last time Nigeria won AFCON was 2013 Niger...
# 6   At the group stages I said to myself if by som...
# 7   Local Man vibes last night at the Super Eagles...
# 8   This is what a person once very highup in then...
# 9   And he has more to say Questions must be asked...
# 10  KAN U believe it Eyes on the AFCON prize for t...
# 11  Nigeria is bringing this home AFCON2023 AFCON2...
# 12  Tonight is the 3rd place match between South A...
# 13  A trophy is on the line A battle of bragging r...
# 14  I rebuke every ancestral eyes watching finals ...
# 15  Link up with the Legend didierdrogba at the BA...
# 16  They really paid The Undertaker millions of do...
# 17  Among Suns soccer PremierLeague West HamArsena...
# 18  Nigeria 0 Ivory Coast 0 ActionBitters iChooseA...
# 19  Before we hear First President to win AFCON Le...
#
#                            date  likes  comments  \
# 0    Feb 10, 2024 · 5:17 PM UTC     26        48
# 1   Feb 10, 2024 · 10:30 AM UTC    630         5
# 2   Feb 10, 2024 · 11:49 AM UTC    891        14
# 3    Feb 10, 2024 · 3:21 PM UTC     32         0
# 4    Feb 10, 2024 · 6:23 AM UTC    166       257
# 5    Feb 10, 2024 · 1:25 PM UTC   4801        50
# 6    Feb 10, 2024 · 7:10 PM UTC      0         0
# 7   Feb 10, 2024 · 11:33 AM UTC     92         6
# 8     Feb 9, 2024 · 8:04 PM UTC    587        74
# 9     Feb 9, 2024 · 8:15 PM UTC    239         7
# 10   Feb 9, 2024 · 11:00 PM UTC   5141        67
# 11   Feb 10, 2024 · 7:13 AM UTC   9515       193
# 12   Feb 10, 2024 · 5:22 AM UTC      5         2
# 13   Feb 10, 2024 · 6:54 PM UTC     24        62
# 14   Feb 10, 2024 · 7:08 PM UTC      0         0
# 15   Feb 10, 2024 · 8:28 AM UTC   1000        10
# 16   Feb 10, 2024 · 7:07 PM UTC      0         0
# 17   Feb 10, 2024 · 7:07 PM UTC      1         0
# 18   Feb 10, 2024 · 7:05 PM UTC      0         0
# 19   Feb 10, 2024 · 6:20 PM UTC      7         4
#
#                                                tokens  \
# 0   [Final, AFCON, Action, Predict, the, final, sc...
# 1   [Ne, perdons, pas, de, vue, lobjectif, mohamme...
# 2   [Captain, Ahmedmusa718, is, special, important...
# 3   [If, you, dont, know, whats, happening, in, DR...
# 4   [Its, the, FINALS, Predict, the, correct, scor...
# 5   [The, last, time, Nigeria, won, AFCON, was, 20...
# 6   [At, the, group, stages, I, said, to, myself, ...
# 7   [Local, Man, vibes, last, night, at, the, Supe...
# 8   [This, is, what, a, person, once, very, highup...
# 9   [And, he, has, more, to, say, Questions, must,...
# 10  [KAN, U, believe, it, Eyes, on, the, AFCON, pr...
# 11  [Nigeria, is, bringing, this, home, AFCON2023,...
# 12  [Tonight, is, the, 3rd, place, match, between,...
# 13  [A, trophy, is, on, the, line, A, battle, of, ...
# 14  [I, rebuke, every, ancestral, eyes, watching, ...
# 15  [Link, up, with, the, Legend, didierdrogba, at...
# 16  [They, really, paid, The, Undertaker, millions...
# 17  [Among, Suns, soccer, PremierLeague, West, Ham...
# 18  [Nigeria, 0, Ivory, Coast, 0, ActionBitters, i...
# 19  [Before, we, hear, First, President, to, win, ...
#
#                                       normalized_text  \
# 0   final afcon action predict the final score bet...
# 1   ne perdons pas de vue lobjectif mohammedsanogo...
# 2   captain ahmedmusa718 is special important to t...
# 3   if you dont know whats happening in dr congo a...
# 4   its the finals predict the correct score befor...
# 5   the last time nigeria won afcon was 2013 niger...
# 6   at the group stages i said to myself if by som...
# 7   local man vibes last night at the super eagles...
# 8   this is what a person once very highup in then...
# 9   and he has more to say questions must be asked...
# 10  kan u believe it eyes on the afcon prize for t...
# 11  nigeria is bringing this home afcon2023 afcon2...
# 12  tonight is the 3rd place match between south a...
# 13  a trophy is on the line a battle of bragging r...
# 14  i rebuke every ancestral eyes watching finals ...
# 15  link up with the legend didierdrogba at the ba...
# 16  they really paid the undertaker millions of do...
# 17  among suns soccer premierleague west hamarsena...
# 18  nigeria 0 ivory coast 0 actionbitters ichoosea...
# 19  before we hear first president to win afcon le...
#
#                                text_without_stopwords sentiment
# 0   Final AFCON Action Predict final score Nigeria...  Positive
# 1   Ne perdons pas de vue lobjectif mohammedsanogo...   Neutral
# 2   Captain Ahmedmusa718 special important team as...  Positive
# 3   dont know whats happening DR Congo national pl...  Positive
# 4   FINALS Predict correct score kickoff tomorrows...  Positive
# 5   last time Nigeria AFCON 2013 Nigeria defeated ...  Positive
# 6   group stages said chance make finals trophy co...  Negative
# 7   Local Man vibes last night Super Eagles camp B...  Positive
# 8   person highup thenff sent evening publish word...  Positive
# 9   say Questions must asked thenff intend spend 7...  Positive
# 10  KAN U believe Eyes AFCON prize Nigerian Super ...  Positive
# 11    Nigeria bringing home AFCON2023 AFCON2024 AFCON   Neutral
# 12  Tonight 3rd place match South Africa Democrati...  Positive
# 13  trophy line battle bragging rights matchup eve...  Negative
# 14  rebuke every ancestral eyes watching finals to...  Negative
# 15  Link Legend didierdrogba BAL Abidjan event las...  Positive
# 16  really paid Undertaker millions dollars 10 sec...   Neutral
# 17  Among Suns soccer PremierLeague West HamArsena...  Positive
# 18  Nigeria 0 Ivory Coast 0 ActionBitters iChooseA...   Neutral
# 19  hear First President win AFCON Let put clearly...  Positive

# %%
#Count the sentiments
df['sentiment'].value_counts()
# Out:
# sentiment
# Positive    58
# Neutral     29
# Negative    13
# Name: count, dtype: int64

# %% [markdown]
# ## Visualization and Analysis

# %%
# Plot the pie chart

#Sentiment Distribution
sentiment_counts = df['sentiment'].value_counts()

#Set the parameters and plot the chart on pie chart
labels = sentiment_counts.index
sizes = sentiment_counts.values
colors = ['gold', 'lightcoral', 'lightskyblue']
explode = (0.1, 0.1, 0)  # slice the pie chart for more emphasis

plt.figure(figsize=(10, 7))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

# Ensure Equal aspect ratio.
plt.axis('equal')
# Out:
# (-1.1491413673106943,
#  1.1814038054856166,
#  -1.1979727027198843,
#  1.1733952589988892)

# %% [markdown]
# ## Result Interpretation

# %% [markdown]
# The analysis indicates that the majority of sentiments are positive, with 58% of the sentiments expressing satisfaction or approval. A significant portion of the sentiments are neutral (29%), indicating a balanced or indifferent reaction. Negative sentiments constitute 13% of the total, suggesting that a minority of individuals have had unfavorable experiences or views. Overall, the sentiment leans strongly towards positive feedback, which is encouraging. However, the presence of negative sentiments highlights areas for potential improvement.

# %% [markdown]
# ## Reflection on the Overall Process

# %% [markdown]
# ### The sentiment analysis process involved several key steps:
#
# <b>1. Data Collection and Preparation:</b> Gathering relevant text data and ensuring it was in a clean, analyzable format. <br><br>
# <b>2. Sentiment Categorization:</b> Using tools such as NLTK to categorize each piece of text as positive, neutral, or negative. <br><br>
# <b>3. Data Analysis:</b> Calculating the frequency and percentage of each sentiment category. <br><br>
# <b>4. Visualization and Interpretation:</b> Plotting the sentiment distribution in a pie chart and interpreting the results.
# <br><br>
# Throughout this process, the importance of data quality and preprocessing became evident. Cleaning the text to remove duplicates and irrelevant characters was crucial for accurate sentiment analysis. The use of reliable sentiment analysis tools provided valuable insights, although it is important to note that automated tools can sometimes misinterpret context, particularly in nuanced or sarcastic expressions. <br><br>
#
# The visualization step, using pie charts, effectively communicated the sentiment distribution, making it easier to understand and present the findings. The overall process demonstrated the power of sentiment analysis in transforming qualitative feedback into quantitative data that can drive informed decision-making.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The analysis shows a predominantly positive sentiment among the subjects, reflecting overall satisfaction. However, the presence of neutral and negative sentiments indicates areas where improvements can be made. This process underscores the value of sentiment analysis as a tool for gaining actionable insights from textual data, enabling businesses and organizations to better understand and respond to their audience's needs and opinions.
